# %%
doors = ["certo", "errado", "errado"]
# Out:
# 3-element Vector{String}:
#  "certo"
#  "errado"
#  "errado"

# %%
person_points = 0;
n = 10000000
for i ∈ 1:n
    global person_points
    persons_choice = rand(doors)
    person_points += persons_choice == "certo" ? 1 : 0
end

println("Keep Wins: $person_points, Change Wins: $(n - person_points)");
println(person_points*2)
# Out:
# Keep Wins: 3334478, Change Wins: 6665522
# 6668956
